# %%
import pandas as pd
#import pandas_profiling as pp
df_AAPL=pd.read_csv('AAPL.csv')
df_GOOG=pd.read_csv('GOOG.csv')
df_META=pd.read_csv('META.csv')

# df_AAPL.info()
#pp.ProfileReport(df_AAPL)
#pp.ProfileReport(df_GOOG)
#pp.ProfileReport(df_META)

# %%
df_AAPL.describe()#done
# Out:
#               Open         High          Low        Close    Adj_Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean     91.384958    92.458712    90.362069    91.454225    90.199795
# std      46.486659    47.073212    45.894307    46.503385    46.916973
# min      35.994999    36.430000    35.500000    35.547501    34.366501
# 25%      47.700626    47.993125    47.342500    47.728126    45.948514
# 50%      73.606251    75.067498    72.197502    73.431247    72.169048
# 75%     134.822502   136.004998   133.347504   134.665001   133.449436
# max     182.630005   182.940002   179.119995   182.009995   181.259918
#
#              Volume
# count  1.258000e+03
# mean   1.184572e+08
# std    5.537336e+07
# min    4.100000e+07
# 25%    8.144868e+07
# 50%    1.039580e+08
# 75%    1.384714e+08
# max    4.265100e+08

# %%
df_GOOG.describe()
# Out:
#               Open         High          Low        Close    Adj_Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean     82.917198    83.819417    82.059701    82.955348    82.955348
# std      32.289462    32.609887    31.925553    32.253445    32.253445
# min      45.870998    46.104000    45.485001    45.750000    45.750000
# 25%      56.426002    57.114000    55.858463    56.584373    56.584373
# 50%      67.827499    68.570598    67.301350    67.804253    67.804253
# 75%     113.282623   114.807499   112.140499   113.340628   113.340628
# max     151.863495   152.100006   149.887497   150.709000   150.709000
#
#              Volume
# count  1.258000e+03
# mean   3.101123e+07
# std    1.359666e+07
# min    6.936000e+06
# 25%    2.245000e+07
# 50%    2.780200e+07
# 75%    3.531300e+07
# max    1.241400e+08

# %%
df_META.describe()
# Out:
#               Open         High          Low        Close    Adj_Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    221.179340   224.112289   218.272170   221.218792   221.218792
# std      63.227194    63.883962    62.596820    63.248667    63.248667
# min     123.099998   129.740005   123.019997   124.059998   124.059998
# 25%     175.350002   177.247498   173.067498   175.285003   175.285003
# 50%     194.720001   197.394996   192.169998   194.595001   194.595001
# 75%     267.930008   270.452499   263.959999   266.937508   266.937508
# max     381.679993   384.329987   378.809998   382.179993   382.179993
#
#              Volume
# count  1.258000e+03
# mean   2.245619e+07
# std    1.445829e+07
# min    6.046300e+06
# 25%    1.418762e+07
# 50%    1.888235e+07
# 75%    2.601525e+07
# max    1.881199e+08

# %%
#daily stock price trend chart
import matplotlib.pyplot as plt

# plt.style.use('ggplot')
# fig,ax=plt.subplots(3)
# df_AAPL.Close.plot(ax=ax[0],color='red',legend=True)
# df_GOOG.Close.plot(ax=ax[1],color='green',legend=True)
# df_META.Close.plot(ax=ax[2],color='blue',legend=True)
# plt.show()

# %%
#put three charts togethor
df_AAPL.Close.plot(legend=True)
df_GOOG.Close.plot(legend=True)
df_META.Close.plot(legend=True)
plt.show()

# %%
#daily turnover trend chart
fig,ax=plt.subplots(3)
df_AAPL.Volume.plot(ax=ax[0],color='red',legend=True)
df_GOOG.Volume.plot(ax=ax[1],color='green',legend=True)
df_META.Volume.plot(ax=ax[2],color='blue',legend=True)
plt.show()

# %%
#Close & Adj Close

#AAPL
from matplotlib.pyplot import legend

df_AAPL.Close.plot(color='red',legend=True)
df_AAPL.Adj_Close.plot(color='black',legend=True)
plt.show()

# %%
#GOOG
df_GOOG.Close.plot(color='red',legend=True)
df_GOOG.Adj_Close.plot(color='black',legend=True)
plt.show()

# %%
#META
df_META.Close.plot(color='red',legend=True)
df_META.Adj_Close.plot(color='black',legend=True)
plt.show()

# %%
#Close & Adj Close Histogram 
fig,ax=plt.subplots(3,2)
df_AAPL.Close.hist(ax=ax[0,0],color='red',legend=True)
df_AAPL.Adj_Close.hist(ax=ax[0,1],color='Black',legend=True)
df_GOOG.Close.hist(ax=ax[1,0],color='red',legend=True)
df_GOOG.Adj_Close.hist(ax=ax[1,1],color='Black',legend=True)
df_META.Close.hist(ax=ax[2,0],color='red',legend=True)
df_META.Adj_Close.hist(ax=ax[2,1],color='Black',legend=True)
plt.show()

# %%
#company info
company={'name':['AAPL','GOOG','META'],'industry':['Consumer Electronics','Internet Content & Information','Internet Content & Information'],'total_revenue':[365817,257637,117929],'net_income':[94680,76033,39370]}
df=pd.DataFrame(company)
print(df)
# Out:
#    name                        industry  total_revenue  net_income
# 0  AAPL            Consumer Electronics         365817       94680
# 1  GOOG  Internet Content & Information         257637       76033
# 2  META  Internet Content & Information         117929       39370

# %%
# market value & daily turnover
from turtle import color


fig,ax=plt.subplots(1,2)
df.total_revenue.plot.bar(ax=ax[0],color='black',legend=True).set_xticks([0,1,2],['AAPL','GOOG','META'],rotation=30)
df.net_income.plot.bar(ax=ax[0],color='purple',legend=True).set_xticks([0,1,2],['AAPL','GOOG','META'],rotation=30)
df_AAPL.Volume.plot(ax=ax[1],color='red',legend=True)
df_GOOG.Volume.plot(ax=ax[1],color='green',legend=True)
df_META.Volume.plot(ax=ax[1],color='blue',legend=True)
plt.show()

# %%
# Risk & Return forecasting
df_AAPL['daily_ret']=df_AAPL.Adj_Close.pct_change()
df_GOOG['daily_ret']=df_GOOG.Adj_Close.pct_change()
df_META['daily_ret']=df_META.Adj_Close.pct_change()

# %%
df_AAPL.daily_ret.plot(color='red',legend=True)
df_GOOG.daily_ret.plot(color='green',legend=True)
df_META.daily_ret.plot(color='blue',legend=True)
plt.show()

# %%
print(f'At 95% confidence interval,the loss isn\'t exceed.\nAAPL: {abs(df_AAPL.daily_ret.quantile(0.05)*100):.3f}%\nGOOG: {abs(df_GOOG.daily_ret.quantile(0.05)*100):.3f}%\nMETA: {abs(df_META.daily_ret.quantile(0.05)*100):.3f}%')
# Out:
# At 95% confidence interval,the loss isn't exceed.
# AAPL: 3.097%
# GOOG: 3.035%
# META: 3.933%
